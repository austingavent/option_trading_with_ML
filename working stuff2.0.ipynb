# %%
import pandas as pd
from pprint import pprint as pp
from itertools import combinations
from pathlib import Path
import requests
import numpy as np
from bokeh.io import output_notebook, curdoc  # output_file
from bokeh.plotting import figure, show
from bokeh.sampledata.iris import flowers
from bokeh.sampledata.iris import flowers as iris_df
from bokeh.models import ColumnDataSource, HoverTool, CategoricalColorMapper, Slider, Column, Select
from bokeh.models import CheckboxGroup, RadioGroup, Toggle, Button
from bokeh.models.widgets import Tabs, Panel
from bokeh.layouts import row, column, gridplot, widgetbox
from bokeh.palettes import Spectral6
from bokeh.themes import Theme
import yaml
from bokeh.models import BoxSelectTool
import bokeh.models

df = pd.read_csv('second_full.csv')
df['pos_percentage'] = round(df['positive%'], 3)

# %%
#Working hovertools, drop down, and colored by risk
def bkapp(doc):
    # Create ColumnDataSource: source
    source = ColumnDataSource(data={
        'x' : df.cost_sum,
        'y' : df.profit_sum,
        'perimeter' : df.perimeter,
        'pos_percentage' : df.pos_percentage,
        'sector' : df.sector,
        'risk' : df.risk,
        'strategy' : df.strategy,
        'symbol' : df.symbol,
        'ROI' : df.ROI
        #source = source
    })
    
    #Create the color map
    mapper = CategoricalColorMapper( factors=['big_aggressive', 'mid_aggressive', 'aggressive', 'middle', 'conservative', 'big_conservative'], 
                                    palette=['red', 'orange', 'yellow', 'green', 'blue', 'purple'])
    
    plot = figure(plot_width = 900, plot_height=900, x_axis_label='Cost Sum', y_axis_label='Profit Sum')
    plot.circle('x', 'y', size=10, source=source, color=dict(field = 'risk', transform = mapper), legend = 'risk')

    # Define a callback function: update_plot
    def update_plot(attr, old, new):
        
        symbol.options = df.loc[df['sector'] == select.value].symbol.unique().tolist()
        
        #update source.data
        source.data = {
            'x' : df.loc[df['symbol'] == symbol.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].cost_sum,
            'y' : df.loc[df['symbol'] == symbol.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].profit_sum,
            'perimeter' : df.loc[df['symbol'] == symbol.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].perimeter,
            'pos_percentage' : df.loc[df['symbol'] == symbol.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].pos_percentage,
            'sector' : df.loc[df['symbol'] == symbol.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].sector,
            'risk' : df.loc[df['symbol'] == symbol.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].risk,
            'strategy' : df.loc[df['symbol'] == symbol.value].loc[df['signal'] == signal.value].strategy,
            'symbol' : df.loc[df['symbol'] == symbol.value].loc[df['signal'] == signal.value].symbol,
            'ROI' : df.loc[df['symbol'] == symbol.value].loc[df['signal'] == signal.value].ROI
        }
        

    # Create a dropdown Select widget for each screening filter
    select = Select(title="sector", options=df.sector.unique().tolist(), value='tech')
    symbol = Select(title="symbol", options=df.symbol.unique().tolist(), value='aapl')
    signal = Select(title="signal", options=df.signal.unique().tolist(), value='RF')
    strategy = Select(title="strategy", options=df.strategy.unique().tolist(), value='bp')
    
    # Attach the update_plot callback to the 'value' property of select
    select.on_change('value', update_plot)
    symbol.on_change('value', update_plot)
    signal.on_change('value', update_plot)
    strategy.on_change('value', update_plot)
    
    #Add hovertools
    hover = HoverTool(tooltips=[('perimeter', '@perimeter'), ('pos_percentage', '@pos_percentage'), ('sector', '@sector'), ('strategy', '@strategy'), ('symbol', '@symbol'), ('ROI', '@ROI')])
    plot.add_tools(hover)
    
    doc.add_root(column(select, symbol, signal, strategy, plot))
    doc.theme = Theme(json=yaml.load("""
        attrs:
            Figure:
                background_fill_color: "#DDDDDD"
                outline_line_color: white
                toolbar_location: above
                height: 400
                width: 400
            Grid:
                grid_line_dash: [6, 4]
                grid_line_color: white
    """, Loader=yaml.FullLoader))

# %%
#Working hovertools, drop down, and colored by risk
def bkapp(doc):
    # Create ColumnDataSource: source
    source = ColumnDataSource(data={
        'x' : df.cost_sum,
        'y' : df.profit_sum,
        'perimeter' : df.perimeter,
        'pos_percentage' : df.pos_percentage,
        'sector' : df.sector,
        'risk' : df.risk,
        'strategy' : df.strategy,
        'symbol' : df.symbol,
        'ROI' : df.ROI
        #source = source
    })
    
    #Create the color map
    mapper = CategoricalColorMapper( factors=['big_aggressive', 'mid_aggressive', 'aggressive', 'middle', 'conservative', 'big_conservative'], 
                                    palette=['red', 'orange', 'yellow', 'green', 'blue', 'purple'])
    
    plot = figure(plot_width = 900, plot_height=900, x_axis_label='Cost Sum', y_axis_label='Profit Sum')
    plot.circle('x', 'y', size=10, source=source, color=dict(field = 'risk', transform = mapper), legend = 'risk')

    # Define a callback function: update_plot
    def update_plot(attr, old, new):
        
        select1.options = df.loc[df['sector'] == select.value].symbol.unique().tolist()
        
        #update source.data
        source.data = {
            'x' : df.loc[df['symbol'] == select1.value].loc[df['signal'] == select2.value].loc[df['strategy'] == select3.value].cost_sum,
            'y' : df.loc[df['symbol'] == select1.value].loc[df['signal'] == select2.value].loc[df['strategy'] == select3.value].profit_sum,
            'perimeter' : df.loc[df['symbol'] == select1.value].loc[df['signal'] == select2.value].loc[df['strategy'] == select3.value].perimeter,
            'pos_percentage' : df.loc[df['symbol'] == select1.value].loc[df['signal'] == select2.value].loc[df['strategy'] == select3.value].pos_percentage,
            'sector' : df.loc[df['symbol'] == select1.value].loc[df['signal'] == select2.value].loc[df['strategy'] == select3.value].sector,
            'risk' : df.loc[df['symbol'] == select1.value].loc[df['signal'] == select2.value].loc[df['strategy'] == select3.value].risk,
            'strategy' : df.loc[df['symbol'] == select1.value].loc[df['signal'] == select2.value].strategy,
            'symbol' : df.loc[df['symbol'] == select1.value].loc[df['signal'] == select2.value].symbol,
            'ROI' : df.loc[df['symbol'] == select1.value].loc[df['signal'] == select2.value].ROI
        }
        

    # Create a dropdown Select widget for each screening filter
    select = Select(title="sector", options=df.sector.unique().tolist(), value='tech')
    select1 = Select(title="symbol", options=df.symbol.unique().tolist(), value='aapl')
    select2 = Select(title="signal", options=df.signal.unique().tolist(), value='RF')
    select3 = Select(title="strategy", options=df.strategy.unique().tolist(), value='bp')
    
    # Attach the update_plot callback to the 'value' property of select
    select.on_change('value', update_plot)
    select1.on_change('value', update_plot)
    select2.on_change('value', update_plot)
    select3.on_change('value', update_plot)
    
    #Add hovertools
    hover = HoverTool(tooltips=[('perimeter', '@perimeter'), ('pos_percentage', '@pos_percentage'), ('sector', '@sector')])
    plot.add_tools(hover)
    
    doc.add_root(column(select, select1, select2, select3, plot))
    doc.theme = Theme(json=yaml.load("""
        attrs:
            Figure:
                background_fill_color: "#DDDDDD"
                outline_line_color: white
                toolbar_location: above
                height: 400
                width: 400
            Grid:
                grid_line_dash: [6, 4]
                grid_line_color: white
    """, Loader=yaml.FullLoader))

# %%
output_notebook()
show(bkapp)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1535">Loading BokehJS ...</span>
#     </div>
# <script id="1536">
#   var xhr = new XMLHttpRequest()
#   xhr.responseType = 'blob';
#   xhr.open('GET', "http://localhost:51994/autoload.js?bokeh-autoload-element=1536&bokeh-absolute-url=http://localhost:51994&resources=none", true);
#
#   xhr.onload = function (event) {
#     var script = document.createElement('script'),
#     src = URL.createObjectURL(event.target.response);
#     script.src = src;
#     document.body.appendChild(script);
#   };
# xhr.send();
# </script>
# ...

# %%
df
# Out:
#        Unnamed: 0                                              index    ROI  \
# 0               0          bp_LSTM.voltrack_20days.-0.01%_profit_CPG  2.333
# 1               1  bpsp_LSTM.shifted.LSTM.voltrack_10days.0.04%_p...  2.143
# 2               2         bpsp_LSTM.voltrack_10days.0.04%_profit_CPG  2.143
# 3               3    bpsp_LSTM.LSTM.voltrack_10days.0.04%_profit_CPG  2.143
# 4               4  bpsp_LSTM.LSTM.shifted.LSTM.voltrack_10days.0....  2.143
# ...           ...                                                ...    ...
# 27225       27225                   spsp_RF_20days.0.04%_profit_TSLA -0.304
# 27226       27226      spsp_LSTM.shifted.RF_20days.0.04%_profit_TSLA -0.366
# 27227       27227  spsp_LSTM.LSTM.shifted.LSTM.voltrack_20days.-0... -0.498
# 27228       27228  spsp_LSTM.LSTM.voltrack.LSTM.shifted_20days.-0... -0.498
# 27229       27229  spsp_LSTM.shifted.LSTM.voltrack_20days.-0.05%_... -0.505
#
# ...

# %%
#    hover = HoverTool(tooltips=[('perimeter', '@perimeter'), ('pos_percentage', '@pos_percentage'), ('sector', '@sector'), ('strategy', '@strategy'), ('symbol', '@symbol'), ('ROI', '@ROI')])

# %%
############scrapbook


#Working hovertools, drop down, and colored by risk
####
#need to create all categories

from bokeh.palettes import Spectral6

def bkapp(doc):
    # Create ColumnDataSource: source
    source = ColumnDataSource(data={
        'x' : df.cost_sum,
        'y' : df.profit_sum,
        'perimeter' : df.perimeter,
        'pos_percentage' : df.pos_percentage,
        'sector' : df.sector,
        'risk' : df.risk,
        'strategy' : df.strategy,
        'symbol' : df.symbol,
        'ROI' : df.ROI
    })
    
    
    mapper = CategoricalColorMapper( factors= df.risk.unique().tolist(), 
                                    palette=Spectral6)
    
    plot = figure(plot_width = 900, plot_height=900, x_axis_label='Cost Sum', y_axis_label='Profit Sum')
    plot.circle('x', 'y', size=5, source=source, color=dict(field = 'risk', transform = mapper), legend = 'risk')
    

    
    
    # Define a callback function: update_plot
    def update_plot(attr, old, new):
        signal.options = first(select.value)
        signal.options = df.signal.unique().tolist() + ['all']
        strategy.options = df.strategy.unique().tolist() + ['all']
        source.data = sourcer(select.value, signal.value, signal.value, strategy.value)
#         if select.value == 'all results':
#             signal.options = ['choopie', 'doopie']
#             signal.options = ["bananas"]
        
#        signal.options = df.loc[df['sector'] == select.value].symbol.unique().tolist()
        
    

#         source.data = {
#             'x' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].cost_sum,
#             'y' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].profit_sum,
#             'perimeter' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].perimeter,
#             'pos_percentage' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].pos_percentage,
#             'sector' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].sector,
#             'risk' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].risk
#         }
        
    #try adding plot after renewed source
#         plot.circle('x', 'y', size=5, source=source, color=dict(field = 'risk', transform = mapper), legend = 'risk')
#         plot = figure(tools="pan,wheel_zoom,box_zoom,reset")
#         plot.add_tools(BoxSelectTool(dimensions="width"))
#####################################

    # Create a dropdown Select widget: select
    select = Select(title="sector", options=df.sector.unique().tolist() + ['all'], value='tech')

    signal = Select(title="symbol", options=df.symbol.unique().tolist(), value='aapl')
    signal = Select(title="signal", options=df.signal.unique().tolist() + ['all'], value='RF')
    strategy = Select(title="strategy", options=df.strategy.unique().tolist() + ['all'], value='bp')
    
    # Attach the update_plot callback to the 'value' property of select
    select.on_change('value', update_plot)
    signal.on_change('value', update_plot)
    signal.on_change('value', update_plot)
    strategy.on_change('value', update_plot)
    
    hover = HoverTool(tooltips=[('perimeter', '@perimeter'), ('pos_percentage', '@pos_percentage'), ('sector', '@sector'), ('strategy', '@strategy'), ('symbol', '@symbol'), ('ROI', '@ROI')])

    # Add the HoverTool to the plot
    plot.add_tools(hover)
    #plot.add_tools(WheelZoomTool())
    #tools = [BoxZoomTool(), ResetTool()]

    doc.add_root(column(select, signal, signal, strategy, plot))

    doc.theme = Theme(json=yaml.load("""
        attrs:
            Figure:
                background_fill_color: "#DDDDDD"
                outline_line_color: white
                toolbar_location: above
                height: 400
                width: 400
            Grid:
                grid_line_dash: [6, 4]
                grid_line_color: white
    """, Loader=yaml.FullLoader))

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'ROI', 'profit_sum', 'cost_sum', 'positives',
#        'negatives', 'min', 'mean', '75%', '50%', '25%', 'cost_mean',
#        'return_mean', 'return_std', 'return_max', 'return_75%', 'return_50%',
#        'symbol', 'strategy', 'signal', 'perimeter', 'sell_big_conservative',
#        'sell_mid_conservative', 'sell_middle', 'sell_aggressive',
#        'sell_mid_aggressive', 'sell_big_aggressive', 'buy_big_conservative',
#        'buy_conservative', 'buy_middle', 'buy_aggressive',
#        'buy_mid_aggressive', 'buy_big_aggressive', 'risk', 'etf', 'materials',
#        'media', 'tech', 'finance', 'military', 'food', 'sector', 'positive%',
#        'pos_percentage'],
#       dtype='object')

# %%
from bokeh.models import BoxSelectTool

# plot = figure(tools="pan,wheel_zoom,box_zoom,reset")
# plot.add_tools(BoxSelectTool(dimensions="width"))

# %%
first = 'hi'
second = 'hi'
if first and second == 'hi':
    print(True)
# Out:
# True

# %%
def returnallGroupallSignal(signal, strategy):
    allGroupallSignal = {
            'x' : df.loc[df['strategy'] == strategy].loc[df['signal'] == signal].cost_sum,
            'y' : df.loc[df['strategy'] == strategy].loc[df['signal'] == signal].profit_sum,
            'perimeter' : df.loc[df['strategy'] == strategy].loc[df['signal'] == signal].perimeter,
            'pos_percentage' : df.loc[df['strategy'] == strategy].loc[df['signal'] == signal].pos_percentage,
            'sector' : df.loc[df['strategy'] == strategy].loc[df['signal'] == signal].sector,
            'risk' : df.loc[df['strategy'] == strategy].loc[df['signal'] == signal].risk}
    return allGroupallSignal

def returnallGroupallSignalallStrategy(signal):
    allGroupallSignalallStrategy = {
            'x' : df.loc[df['signal'] == signal].cost_sum,
            'y' : df.loc[df['signal'] == signal].profit_sum,
            'perimeter' : df.loc[df['signal'] == signal].perimeter,
            'pos_percentage' : df.loc[df['signal'] == signal].pos_percentage,
            'sector' : df.loc[df['signal'] == signal].sector,
            'risk' : df.loc[df['signal'] == signal].risk,
            'risk' : df.loc[df['signal'] == signal].risk,
            'strategy' : df.loc[df['signal'] == signal].strategy,
            'symbol' : df.loc[df['signal'] == signal].symbol,
            'ROI' : df.loc[df['signal'] == signal].ROI
            }
    return allGroupallSignalallStrategy

def sourcer(group, symbol, signal, strategy):
    if (group == 'all') and (strategy != 'all'):
        return returnallGroupallSignal(signal, strategy)
    if strategy == 'all':
        return returnallGroupallSignalallStrategy(signal)
    else:
        nexttry = {
            'x' : df.loc[df['symbol'] == symbol].loc[df['signal'] == signal].cost_sum,
            'y' : df.loc[df['symbol'] == symbol].loc[df['signal'] == signal].profit_sum,
            'perimeter' : df.loc[df['symbol'] == symbol].loc[df['signal'] == signal].perimeter,
            'pos_percentage' : df.loc[df['symbol'] == symbol].loc[df['signal'] == signal].pos_percentage,
            'sector' : df.loc[df['symbol'] == symbol].loc[df['signal'] == signal].sector,
            'risk' : df.loc[df['symbol'] == symbol].loc[df['signal'] == signal].risk,
            'strategy' : df.loc[df['symbol'] == symbol].loc[df['signal'] == signal].strategy,
            'symbol' : df.loc[df['symbol'] == symbol].loc[df['signal'] == signal].symbol,
            'ROI' : df.loc[df['symbol'] == symbol].loc[df['signal'] == signal].ROI            
            }
    #####
    #if risk!= 'all':
    #   change color mapping
    
    
        return nexttry

def first(select):
    if select == 'all':
        print('wowww')
        return ['all symbols']
    else:
        print('sarcastic wow')
        return df.loc[df['sector'] == select].symbol.unique().tolist()

def second(select):
    if select == 'all':
        print('all symbols')
        return df.signal.unique().tolist()
    else:
        print('not all symbols')
        return df.loc[df['symbol'] == select].signal.unique().tolist()

# %%
#add more to hologram- need to see symbol, strategy,

# %%
output_notebook()
show(bkapp)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
# <script id="1003">
#   var xhr = new XMLHttpRequest()
#   xhr.responseType = 'blob';
#   xhr.open('GET', "http://localhost:64360/autoload.js?bokeh-autoload-element=1003&bokeh-absolute-url=http://localhost:64360&resources=none", true);
#
#   xhr.onload = function (event) {
#     var script = document.createElement('script'),
#     src = URL.createObjectURL(event.target.response);
#     script.src = src;
#     document.body.appendChild(script);
#   };
# xhr.send();
# </script>
# ...
# sarcastic wow
# sarcastic wow
# sarcastic wow
# sarcastic wow
# sarcastic wow

# %%
df
# Out:
#        Unnamed: 0                                              index    ROI  \
# 0               0          bp_LSTM.voltrack_20days.-0.01%_profit_CPG  2.333
# 1               1  bpsp_LSTM.shifted.LSTM.voltrack_10days.0.04%_p...  2.143
# 2               2         bpsp_LSTM.voltrack_10days.0.04%_profit_CPG  2.143
# 3               3    bpsp_LSTM.LSTM.voltrack_10days.0.04%_profit_CPG  2.143
# 4               4  bpsp_LSTM.LSTM.shifted.LSTM.voltrack_10days.0....  2.143
# ...           ...                                                ...    ...
# 27225       27225                   spsp_RF_20days.0.04%_profit_TSLA -0.304
# 27226       27226      spsp_LSTM.shifted.RF_20days.0.04%_profit_TSLA -0.366
# 27227       27227  spsp_LSTM.LSTM.shifted.LSTM.voltrack_20days.-0... -0.498
# 27228       27228  spsp_LSTM.LSTM.voltrack.LSTM.shifted_20days.-0... -0.498
# 27229       27229  spsp_LSTM.shifted.LSTM.voltrack_20days.-0.05%_... -0.505
#
# ...

# %%
def get_grouped(sector):
    if sector == 'all results'

# %%
a_lambda_function = lambda x: x*2 if x < 3 else x

x = 2
print(a_lambda_function(x))
OUTPUT

# %%
df.sector.unique()
# Out:
# array(['food', 'tech', 'media', 'finance', 'etf', 'military'],
#       dtype=object)

# %%
#Working hovertools, drop down, and colored by risk

#need to create all categories
tech = ((df.loc[df['tech'] == True]).symbol.unique().tolist())
tech.append('all tech')

food = ((df.loc[df['food'] == True]).symbol.unique().tolist())
food.append('all food')

media = ((df.loc[df['media'] == True]).symbol.unique().tolist())
media.append('all media')

finance = ((df.loc[df['finance'] == True]).symbol.unique().tolist())
finance.append('all finance')

etf = ((df.loc[df['etf'] == True]).symbol.unique().tolist())
etf.append('all etf')

military = ((df.loc[df['military'] == True]).symbol.unique().tolist())
military.append('all military')


symbol_list = df.symbol.unique().tolist()
symbol_list.append('all symbols')
sector_list = df.sector.unique().tolist()
sector_list.append('all sectors')
print(sector_list)
print(symbol_list)
# Out:
# ['food', 'tech', 'media', 'finance', 'etf', 'military', 'all sectors']
# ['CPG', 'FB', 'GOOG', 'MSFT', 'NFLX', 'AAPL', 'DIS', 'GS', 'JPM', 'MTUM', 'PG', 'SBUX', 'TSLA', 'TWTR', 'BA', 'SPY', 'all symbols']

# %%
risk_list = df.risk.unique().tolist()
risk_list.append('all risk')
risk_list
# Out:
# ['aggressive',
#  'big_aggressive',
#  'middle',
#  'mid_aggressive',
#  'conservative',
#  'big_conservative',
#  'all risk']

# %%
def bkapp(doc):
    # Create ColumnDataSource: source
    source = ColumnDataSource(data={
        'x' : df.cost_sum,
        'y' : df.profit_sum,
        'perimeter' : df.perimeter,
        'pos_percentage' : df.pos_percentage,
        'sector' : df.sector,
        'risk' : df.risk
        #source = source
    })
    
    
    mapper = CategoricalColorMapper( factors=['big_aggressive', 'mid_aggressive', 'aggressive', 'middle', 'conservative', 'big_conservative'], 
                                    palette=['red', 'orange', 'yellow', 'green', 'blue', 'purple'])
    
    plot = figure(plot_width = 900, plot_height=900, x_axis_label='Cost Sum', y_axis_label='Profit Sum')
    plot.circle('x', 'y', size=3, source=source, color=dict(field = 'risk', transform = mapper), legend = 'risk')
    # Add circles to the plot
    
    #plot.circle('x', 'y', source=source)
#     color_mapper = CategoricalColorMapper(factors=['Europe', 'Asia', 'US'],
#                                       palette=['red', 'green', 'blue'])
#     # Create a new plot: plot
#     plot = figure()

#     # Add circles to the plot
#     plot.circle('x', 'y', source=source)
    # Define a callback function: update_plot
    def update_plot(attr, old, new):
        
        
        
        
        
        signal.options = df.loc[df['sector'] == select.value].symbol.unique().tolist()
        #signal = Select(title="signal", options=df.signal.unique().tolist(), value='RF')
        #strategy = Select(title="strategy", options=df.strategy.unique().tolist(), value='bp')
    

        source.data = {
            'x' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].cost_sum,
            'y' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].profit_sum,
            'perimeter' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].perimeter,
            'pos_percentage' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].pos_percentage,
            'sector' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].sector,
            'risk' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].risk,
            'strategy' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].strategy,
            'symbol' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].symbol,
            'signal' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].signal


        }
        
        #palette = d3['Category10'][len(df['cat'].unique())]
        #color_map = bmo.CategoricalColorMapper(factors=df['cat'].unique(),
                                           #palette=palette)

        # create figure and plot
        #p = bpl.figure()
        #plot.scatter(x='ss', y='sss', color = 'red')
                  #color={'field': 'cat', 'transform': color_map},
                  #legend='cat', source=source)
        #bpl.show(p)


    # Create a dropdown Select widget: select
    select = Select(title="Grouper", options=sector_list, value='tech')

    signal = Select(title="symbol", options=df.symbol.unique().tolist(), value='aapl')
    signal = Select(title="signal", options=df.signal.unique().tolist(), value='RF')
    strategy = Select(title="strategy", options=df.strategy.unique().tolist(), value='bp')
    select4 = Select(title="risk", options=df.risk.unique().tolist(), value='aggressive')
    # Attach the update_plot callback to the 'value' property of select
    select.on_change('value', update_plot)
    signal.on_change('value', update_plot)
    signal.on_change('value', update_plot)
    strategy.on_change('value', update_plot)
    select4.on_change('value', update_plot)
    hover = HoverTool(tooltips=[('perimeter', '@perimeter'), ('pos_percentage', '@pos_percentage'), ('sector', '@sector'),
                               ('strategy', '@strategy'), ('symbol', '@symbol'), ('signal', '@signal')])

    # Add the HoverTool to the plot
    plot.add_tools(hover)
    #plot.scatter('x', 'y', color = 'red')
    #plot(source = source)
    doc.add_root(column(select, signal, signal, strategy, select4, plot))

    doc.theme = Theme(json=yaml.load("""
        attrs:
            Figure:
                background_fill_color: "#DDDDDD"
                outline_line_color: white
                toolbar_location: above
                height: 400
                width: 400
            Grid:
                grid_line_dash: [6, 4]
                grid_line_color: white
    """, Loader=yaml.FullLoader))

# %%
sector_list
# Out:
# ['food', 'tech', 'media', 'finance', 'etf', 'military', 'all sectors']

# %%
def bkapp(doc):
    # Create ColumnDataSource: source
    source = ColumnDataSource(data={
        'x' : df.cost_sum,
        'y' : df.profit_sum,
        'perimeter' : df.perimeter,
        'pos_percentage' : df.pos_percentage,
        'sector' : df.sector,
        'risk' : df.risk
        #source = source
    })
    
    
    mapper = CategoricalColorMapper( factors=['big_aggressive', 'mid_aggressive', 'aggressive', 'middle', 'conservative', 'big_conservative'], 
                                    palette=['red', 'orange', 'yellow', 'green', 'blue', 'purple'])
    
    plot = figure(plot_width = 900, plot_height=900, x_axis_label='Cost Sum', y_axis_label='Profit Sum')
    plot.circle('x', 'y', size=3, source=source, color=dict(field = 'risk', transform = mapper), legend = 'risk')
    # Add circles to the plot
    
    #plot.circle('x', 'y', source=source)
#     color_mapper = CategoricalColorMapper(factors=['Europe', 'Asia', 'US'],
#                                       palette=['red', 'green', 'blue'])
#     # Create a new plot: plot
#     plot = figure()

#     # Add circles to the plot
#     plot.circle('x', 'y', source=source)
    # Define a callback function: update_plot
    def update_plot(attr, old, new):
        
        
        
        
        
        signal.options = df.loc[df['sector'] == select.value].symbol.unique().tolist()
        #signal = Select(title="signal", options=df.signal.unique().tolist(), value='RF')
        #strategy = Select(title="strategy", options=df.strategy.unique().tolist(), value='bp')
    

        source.data = {
            'x' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].cost_sum,
            'y' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].profit_sum,
            'perimeter' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].perimeter,
            'pos_percentage' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].pos_percentage,
            'sector' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].sector,
            'risk' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].risk,
            'strategy' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].strategy,
            'symbol' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].symbol,
            'signal' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].signal


        }
        
        #palette = d3['Category10'][len(df['cat'].unique())]
        #color_map = bmo.CategoricalColorMapper(factors=df['cat'].unique(),
                                           #palette=palette)

        # create figure and plot
        #p = bpl.figure()
        #plot.scatter(x='ss', y='sss', color = 'red')
                  #color={'field': 'cat', 'transform': color_map},
                  #legend='cat', source=source)
        #bpl.show(p)


    # Create a dropdown Select widget: select
    select = Select(title="Grouper", options=sector_list, value='tech')

    signal = Select(title="symbol", options=df.symbol.unique().tolist(), value='aapl')
    signal = Select(title="signal", options=df.signal.unique().tolist(), value='RF')
    strategy = Select(title="strategy", options=df.strategy.unique().tolist(), value='bp')
    select4 = Select(title="risk", options=df.risk.unique().tolist(), value='aggressive')
    # Attach the update_plot callback to the 'value' property of select
    select.on_change('value', update_plot)
    signal.on_change('value', update_plot)
    signal.on_change('value', update_plot)
    strategy.on_change('value', update_plot)
    select4.on_change('value', update_plot)
    hover = HoverTool(tooltips=[('perimeter', '@perimeter'), ('pos_percentage', '@pos_percentage'), ('sector', '@sector'),
                               ('strategy', '@strategy'), ('symbol', '@symbol'), ('signal', '@signal')])

    # Add the HoverTool to the plot
    plot.add_tools(hover)
    #plot.scatter('x', 'y', color = 'red')
    #plot(source = source)
    doc.add_root(column(select, signal, signal, strategy, select4, plot))

    doc.theme = Theme(json=yaml.load("""
        attrs:
            Figure:
                background_fill_color: "#DDDDDD"
                outline_line_color: white
                toolbar_location: above
                height: 400
                width: 400
            Grid:
                grid_line_dash: [6, 4]
                grid_line_color: white
    """, Loader=yaml.FullLoader))

# %%
def bkapp(doc):
    # Create ColumnDataSource: source
    source = ColumnDataSource(data={
        'x' : df.cost_sum,
        'y' : df.profit_sum,
        'perimeter' : df.perimeter,
        'pos_percentage' : df.pos_percentage,
        'sector' : df.sector,
        'risk' : df.risk
        #source = source
    })
    
    
    mapper = CategoricalColorMapper( factors=['big_aggressive', 'mid_aggressive', 'aggressive', 'middle', 'conservative', 'big_conservative'], 
                                    palette=['red', 'orange', 'yellow', 'green', 'blue', 'purple'])
    
    plot = figure(plot_width = 900, plot_height=900, x_axis_label='Cost Sum', y_axis_label='Profit Sum')
    plot.circle('x', 'y', size=3, source=source, color=dict(field = 'risk', transform = mapper), legend = 'risk')
    # Add circles to the plot
    
    #plot.circle('x', 'y', source=source)
#     color_mapper = CategoricalColorMapper(factors=['Europe', 'Asia', 'US'],
#                                       palette=['red', 'green', 'blue'])
#     # Create a new plot: plot
#     plot = figure()

#     # Add circles to the plot
#     plot.circle('x', 'y', source=source)
    # Define a callback function: update_plot
    def update_plot(attr, old, new):
        signal.options = df.loc[df['sector'] == 'tech'].symbol.unique().tolist() 

        if select.value == 'all sectors':
            print('all')
             
#             source.data = {
#                 'x' : df.loc[df['symbol'] == 'TSLA'].cost_sum,
#                 'y' : df.loc[df['symbol'] == 'TSLA'].profit_sum,
#                 'perimeter' : df.loc[df['symbol'] == 'TSLA'].perimeter,
#                 'pos_percentage' : df.loc[df['symbol'] == 'TSLA'].pos_percentage,
#                 'sector' : df.loc[df['symbol'] == 'TSLA'].sector,
#                 'risk' : df.loc[df['symbol'] == 'TSLA'].risk,
#                 'strategy' : df.loc[df['symbol'] == 'TSLA'].strategy,
#                 'symbol' : df.loc[df['symbol'] == 'TSLA'].symbol,
#                 'signal' : df.loc[df['symbol'] == 'TSLA'].signal}
            
            ####
#             signal = Select(title="symbol", options=symbol_list, value='aapl')
#             signal = Select(title="signal", options=df.signal.unique().tolist(), value='RF')
#             strategy = Select(title="strategy", options=df.strategy.unique().tolist(), value='bp')
#             select4 = Select(title="risk", options=df.risk.unique().tolist(), value='aggressive')
            
#             source.data = {
#                 'x' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].cost_sum,
#                 'y' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].profit_sum,
#                 'perimeter' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].perimeter,
#                 'pos_percentage' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].pos_percentage,
#                 'sector' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].sector,
#                 'risk' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].risk,
#                 'strategy' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].strategy,
#                 'symbol' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].symbol,
#                 'signal' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].signal}

#         else:
#             signal.options = df.loc[df['sector'] == select.value].symbol.unique().tolist()
        #signal = Select(title="signal", options=df.signal.unique().tolist(), value='RF')
        #strategy = Select(title="strategy", options=df.strategy.unique().tolist(), value='bp')
    #####
        else:
            signal.options = df.loc[df['sector'] == 'tech'].symbol.unique().tolist() 
           # signal.options = ((df.loc[df[select.value] == True]).symbol.unique().tolist()) + [f'all of {select.value}']
           # print(select.value)
            ###
#             if signal.value == f'all of {select.value}':
#                  source.data = {
#                     'x' : df.loc[df[select.value] == True].cost_sum,
#                     'y' : df.loc[df[select.value] == True].profit_sum,
#                     'perimeter' : df.loc[df[select.value] == True].perimeter,
#                     'pos_percentage' : df.loc[df[select.value] == True].pos_percentage,
#                     'sector' : df.loc[df[select.value] == True].sector,
#                     'risk' : df.loc[df[select.value] == True].risk,
#                     'strategy' : df.loc[df[select.value] == True].strategy,
#                     'symbol' : df.loc[df[select.value] == True].symbol,
#                     'signal' : df.loc[df[select.value] == True].signal}
                
# #             signal.options = Select(title="signal", options=df.signal.unique().tolist(), value='RF')
# #             strategy.options = Select(title="strategy", options=df.strategy.unique().tolist(), value='bp')
# #             select4.options = Select(title="risk", options=df.risk.unique().tolist(), value='aggressive')            
            
#             source.data = {
#                 'x' : df.loc[df['symbol'] == 'TSLA'].cost_sum,
#                 'y' : df.loc[df['symbol'] == 'TSLA'].profit_sum,
#                 'perimeter' : df.loc[df['symbol'] == 'TSLA'].perimeter,
#                 'pos_percentage' : df.loc[df['symbol'] == 'TSLA'].pos_percentage,
#                 'sector' : df.loc[df['symbol'] == 'TSLA'].sector,
#                 'risk' : df.loc[df['symbol'] == 'TSLA'].risk,
#                 'strategy' : df.loc[df['symbol'] == 'TSLA'].strategy,
#                 'symbol' : df.loc[df['symbol'] == 'TSLA'].symbol,
#                 'signal' : df.loc[df['symbol'] == 'TSLA'].signal}
            
            #######
            
            
#             signal = Select(title= 'symbol', options = (df.loc[df[select.value] == True]).symbol.unique().tolist() + [f'all {select.value}'])
#             signal = Select(title="signal", options=df.signal.unique().tolist(), value='RF')
#             strategy = Select(title="strategy", options=df.strategy.unique().tolist(), value='bp')
#             select4 = Select(title="risk", options=df.risk.unique().tolist(), value='aggressive')
#             source.data = {
#                 'x' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].cost_sum,
#                 'y' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].profit_sum,
#                 'perimeter' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].perimeter,
#                 'pos_percentage' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].pos_percentage,
#                 'sector' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].sector,
#                 'risk' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].risk,
#                 'strategy' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].strategy,
#                 'symbol' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].symbol,
#                 'signal' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].signal}
        
            #plot.circle('x', 'y', size=3, source=source, color=dict(field = 'risk', transform = mapper), legend = 'risk')

        #palette = d3['Category10'][len(df['cat'].unique())]
        #color_map = bmo.CategoricalColorMapper(factors=df['cat'].unique(),
                                           #palette=palette)

        # create figure and plot
        #p = bpl.figure()
        #plot.scatter(x='ss', y='sss', color = 'red')
                  #color={'field': 'cat', 'transform': color_map},
                  #legend='cat', source=source)
        #bpl.show(p)


    # Create a dropdown Select widget: select
    select = Select(title="Grouper", options=sector_list, value='tech')

    signal = Select(title="symbol", options=symbol_list, value='aapl')
    signal = Select(title="signal", options=df.signal.unique().tolist(), value='RF')
    strategy = Select(title="strategy", options=df.strategy.unique().tolist(), value='bp')
    select4 = Select(title="risk", options=df.risk.unique().tolist(), value='aggressive')
    # Attach the update_plot callback to the 'value' property of select
    select.on_change('value', update_plot)
    signal.on_change('value', update_plot)
    signal.on_change('value', update_plot)
    strategy.on_change('value', update_plot)
    select4.on_change('value', update_plot)
    hover = HoverTool(tooltips=[('perimeter', '@perimeter'), ('pos_percentage', '@pos_percentage'), ('sector', '@sector'),
                               ('strategy', '@strategy'), ('symbol', '@symbol'), ('signal', '@signal')])

    # Add the HoverTool to the plot
    plot.add_tools(hover)
    #plot.scatter('x', 'y', color = 'red')
    #plot(source = source)
    doc.add_root(column(select, signal, signal, strategy, select4, plot))

    doc.theme = Theme(json=yaml.load("""
        attrs:
            Figure:
                background_fill_color: "#DDDDDD"
                outline_line_color: white
                toolbar_location: above
                height: 400
                width: 400
            Grid:
                grid_line_dash: [6, 4]
                grid_line_color: white
    """, Loader=yaml.FullLoader))
# Out:
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' content: {'events': [{'kind': 'ModelChanged', 'model': {'id': '6409'}, 'attr': 'value', 'new': 'tech'}], 'references': []}
#  error: UnboundLocalError("local variable 'select1' referenced before assignment")
# Traceback (most recent call last):
#   File "C:\Users\austi\anaconda3\lib\site-packages\bokeh\server\protocol_handler.py", line 90, in handle
#     work = await handler(message, connection)
#   File "C:\Users\austi\anaconda3\lib\site-packages\bokeh\server\session.py", line 67, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "C:\Users\austi\anaconda3\lib\site-packages\bokeh\server\session.py", line 261, in _handle_patch
#     message.apply_to_document(self.document, self)
#   File "C:\Users\austi\anaconda3\lib\site-packages\bokeh\protocol\messages\patch_doc.py", line 100, in apply_to_document
# ...

# %%
def bkapp(doc):
    # Create ColumnDataSource: source
    source = ColumnDataSource(data={
        'x' : df.cost_sum,
        'y' : df.profit_sum,
        'perimeter' : df.perimeter,
        'pos_percentage' : df.pos_percentage,
        'sector' : df.sector,
        'risk' : df.risk
        #source = source
    })
    
    
    mapper = CategoricalColorMapper( factors=['big_aggressive', 'mid_aggressive', 'aggressive', 'middle', 'conservative', 'big_conservative'], 
                                    palette=['red', 'orange', 'yellow', 'green', 'blue', 'purple'])
    
    plot = figure(plot_width = 900, plot_height=900, x_axis_label='Cost Sum', y_axis_label='Profit Sum')
    plot.circle('x', 'y', size=3, source=source, color=dict(field = 'risk', transform = mapper), legend = 'risk')
    # Add circles to the plot
    
    #plot.circle('x', 'y', source=source)
#     color_mapper = CategoricalColorMapper(factors=['Europe', 'Asia', 'US'],
#                                       palette=['red', 'green', 'blue'])
#     # Create a new plot: plot
#     plot = figure()

#     # Add circles to the plot
#     plot.circle('x', 'y', source=source)
    # Define a callback function: update_plot
    def update_plot(attr, old, new):
        
        
        
        
        
        signal.options = get_grouped(select.value)
        #signal = Select(title="signal", options=df.signal.unique().tolist(), value='RF')
        #strategy = Select(title="strategy", options=df.strategy.unique().tolist(), value='bp')
    

        source.data = {
            'x' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].cost_sum,
            'y' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].profit_sum,
            'perimeter' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].perimeter,
            'pos_percentage' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].pos_percentage,
            'sector' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].sector,
            'risk' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].risk,
            'strategy' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].strategy,
            'symbol' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].symbol,
            'signal' : df.loc[df['symbol'] == signal.value].loc[df['signal'] == signal.value].loc[df['strategy'] == strategy.value].signal


        }
        
        #palette = d3['Category10'][len(df['cat'].unique())]
        #color_map = bmo.CategoricalColorMapper(factors=df['cat'].unique(),
                                           #palette=palette)

        # create figure and plot
        #p = bpl.figure()
        #plot.scatter(x='ss', y='sss', color = 'red')
                  #color={'field': 'cat', 'transform': color_map},
                  #legend='cat', source=source)
        #bpl.show(p)


    # Create a dropdown Select widget: select
    select = Select(title="Grouper", options=sector_list, value='tech')

    signal = Select(title="symbol", options=df.symbol.unique().tolist(), value='aapl')
    signal = Select(title="signal", options=df.signal.unique().tolist(), value='RF')
    strategy = Select(title="strategy", options=df.strategy.unique().tolist(), value='bp')
    select4 = Select(title="risk", options=df.risk.unique().tolist(), value='aggressive')
    # Attach the update_plot callback to the 'value' property of select
    select.on_change('value', update_plot)
    signal.on_change('value', update_plot)
    signal.on_change('value', update_plot)
    strategy.on_change('value', update_plot)
    select4.on_change('value', update_plot)
    hover = HoverTool(tooltips=[('perimeter', '@perimeter'), ('pos_percentage', '@pos_percentage'), ('sector', '@sector'),
                               ('strategy', '@strategy'), ('symbol', '@symbol'), ('signal', '@signal')])

    # Add the HoverTool to the plot
    plot.add_tools(hover)
    #plot.scatter('x', 'y', color = 'red')
    #plot(source = source)
    doc.add_root(column(select, signal, signal, strategy, select4, plot))

    doc.theme = Theme(json=yaml.load("""
        attrs:
            Figure:
                background_fill_color: "#DDDDDD"
                outline_line_color: white
                toolbar_location: above
                height: 400
                width: 400
            Grid:
                grid_line_dash: [6, 4]
                grid_line_color: white
    """, Loader=yaml.FullLoader))

# %%
sector_list = df.sector.unique().tolist() + ['all results']
sector_list
# Out:
# ['food', 'tech', 'media', 'finance', 'etf', 'military', 'all results']

# %%
#get the group by-

# %%
def get_grouped(sector):
    if sector == 'all results':
        return df.symbol.unique().tolist()
    if sector == 'tech':
        return (df.loc[df['tech'] == True]).symbol.unique().tolist() + ['all'], 'tech'

# %%
sooper = (get_grouped('tech'))
sooper[0]
# Out:
# ['FB', 'GOOG', 'MSFT', 'AAPL', 'TSLA', 'all']

# %%
yy = ((df.loc[df['tech'] == True]).symbol.unique().tolist()) + ['all']
yy
# Out:
# ['FB', 'GOOG', 'MSFT', 'AAPL', 'TSLA', 'all']

# %%
output_notebook()
show(bkapp)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1186">Loading BokehJS ...</span>
#     </div>
# <script id="1187">
#   var xhr = new XMLHttpRequest()
#   xhr.responseType = 'blob';
#   xhr.open('GET', "http://localhost:61732/autoload.js?bokeh-autoload-element=1187&bokeh-absolute-url=http://localhost:61732&resources=none", true);
#
#   xhr.onload = function (event) {
#     var script = document.createElement('script'),
#     src = URL.createObjectURL(event.target.response);
#     script.src = src;
#     document.body.appendChild(script);
#   };
# xhr.send();
# </script>
# ...

# %%
output_notebook()
show(bkapp)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3919">Loading BokehJS ...</span>
#     </div>
# <script id="3920">
#   var xhr = new XMLHttpRequest()
#   xhr.responseType = 'blob';
#   xhr.open('GET', "http://localhost:52148/autoload.js?bokeh-autoload-element=3920&bokeh-absolute-url=http://localhost:52148&resources=none", true);
#
#   xhr.onload = function (event) {
#     var script = document.createElement('script'),
#     src = URL.createObjectURL(event.target.response);
#     script.src = src;
#     document.body.appendChild(script);
#   };
# xhr.send();
# </script>
# ...
# all
# not all
# not all
# not all
# not all
# not all
# all
# all
# not all

# %%
df
# Out:
#        Unnamed: 0                                              index    ROI  \
# 0               0          bp_LSTM.voltrack_20days.-0.01%_profit_CPG  2.333
# 1               1  bpsp_LSTM.shifted.LSTM.voltrack_10days.0.04%_p...  2.143
# 2               2         bpsp_LSTM.voltrack_10days.0.04%_profit_CPG  2.143
# 3               3    bpsp_LSTM.LSTM.voltrack_10days.0.04%_profit_CPG  2.143
# 4               4  bpsp_LSTM.LSTM.shifted.LSTM.voltrack_10days.0....  2.143
# ...           ...                                                ...    ...
# 27225       27225                   spsp_RF_20days.0.04%_profit_TSLA -0.304
# 27226       27226      spsp_LSTM.shifted.RF_20days.0.04%_profit_TSLA -0.366
# 27227       27227  spsp_LSTM.LSTM.shifted.LSTM.voltrack_20days.-0... -0.498
# 27228       27228  spsp_LSTM.LSTM.voltrack.LSTM.shifted_20days.-0... -0.498
# 27229       27229  spsp_LSTM.shifted.LSTM.voltrack_20days.-0.05%_... -0.505
#
# ...

# %%
hs = ((df.loc[df['tech'] == True]).symbol.unique().tolist())
hs
# Out:
# ['FB', 'GOOG', 'MSFT', 'AAPL', 'TSLA']

# %%
mfs = df.symbol.unique().tolist()
mfs
# Out:
# ['CPG',
#  'FB',
#  'GOOG',
#  'MSFT',
#  'NFLX',
#  'AAPL',
#  'DIS',
#  'GS',
#  'JPM',
#  'MTUM',
#  'PG',
#  'SBUX',
#  'TSLA',
#  'TWTR',
#  'BA',
#  'SPY']

# %%
mfs.append('all sectors')
mfs
# Out:
# ['CPG',
#  'FB',
#  'GOOG',
#  'MSFT',
#  'NFLX',
#  'AAPL',
#  'DIS',
#  'GS',
#  'JPM',
#  'MTUM',
#  'PG',
#  'SBUX',
#  'TSLA',
#  'TWTR',
#  'BA',
#  'SPY',
#  'all sectors']
